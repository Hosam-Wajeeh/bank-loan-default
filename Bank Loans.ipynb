# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
dataset = pd.read_csv('Dataset3.csv')
dataset.shape
# Out:
# (42535, 36)

# %%
dataset.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       2850         2850           2850.0   36 months   11.83%        94.44
# 1      20000        20000          19950.0   60 months   17.14%       498.56
# 2       6000         4500              0.0   36 months   15.70%       157.55
# 3       6400         6400           6150.0   60 months   10.59%       137.85
# 4       1200         1200           1200.0   36 months   13.85%        40.93
#
#   grade sub_grade  emp_length home_ownership  annual_inc verification_status  \
# 0     B        B3           5            OWN     24000.0        Not Verified
# 1     E        E3          10       MORTGAGE     48012.0            Verified
# 2     E        E5           1       MORTGAGE     42450.0        Not Verified
# 3     B        B2          10       MORTGAGE     37000.0        Not Verified
# 4     C        C4           5            OWN     60000.0        Not Verified
#
#    issue_days Credit_requirements             purpose  zip_code addr_state  \
# 0         347                 Yes  debt_consolidation     33100         FL
# 1         256                 Yes  debt_consolidation     33100         FL
# 2         137                  No         educational     66200         KS
# 3         226                 Yes  debt_consolidation     32100         FL
# 4         316                 Yes               other     17600         PA
#
#      dti  delinq_2yrs  earliest_cr_line  inq_last_6mths  \
# 0  24.70            0              6718               2
# 1  13.82            2             11528               0
# 2  23.89            0               112              12
# 3  15.70            0              7630               0
# 4   3.08            0                17               3
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                       0                       0         5        0
# 1                      13                       0        13        0
# 2                      58                       0        15        0
# 3                       0                       0         9        0
# 4                       0                       0         3        0
#
#    revol_bal revol_util  total_acc  total_pymnt  total_pymnt_inv  \
# 0       4184     38.70%          6      3228.32          3228.32
# 1      14890     66.20%         36     29710.84         29636.67
# 2       5361     42.20%         19      4836.50             0.00
# 3       8254     48.10%         17      7306.05          7019.34
# 4       2823     65.70%          8       501.76           501.76
#
#    last_pymnt_d  last_pymnt_amnt  next_pymnt_d  last_credit_pull_d  \
# 0           314            51.00             0                 128
# 1           283           498.56             0                 128
# 2           316           157.55           166                  67
# 3            39           137.85             0                  67
# 4            75            40.93             0                  67
#
#    pub_rec_bankruptcies  loan_status
# 0                     0  Charged Off
# 1                     0  Charged Off
# 2                     0  Charged Off
# 3                     0  Charged Off
# 4                     0  Charged Off

# %%
dataset['loan_status'].value_counts()
# Out:
# Fully Paid     36104
# Charged Off     6431
# Name: loan_status, dtype: int64

# %%
sns.countplot(x='loan_status', data=dataset)
plt.show()

# %% [markdown]
# Note: The data is imbalanced

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42535 entries, 0 to 42534
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   loan_amnt               42535 non-null  int64
#  1   funded_amnt             42535 non-null  int64
#  2   funded_amnt_inv         42535 non-null  float64
#  3   term                    42535 non-null  object
#  4   int_rate                42535 non-null  object
#  5   installment             42535 non-null  float64
#  6   grade                   42535 non-null  object
#  7   sub_grade               42535 non-null  object
#  8   emp_length              42535 non-null  int64
#  9   home_ownership          42535 non-null  object
#  10  annual_inc              42531 non-null  float64
#  11  verification_status     42535 non-null  object
#  12  issue_days              42535 non-null  int64
#  13  Credit_requirements     42535 non-null  object
#  14  purpose                 42535 non-null  object
#  15  zip_code                42535 non-null  int64
#  16  addr_state              42535 non-null  object
#  17  dti                     42535 non-null  float64
#  18  delinq_2yrs             42535 non-null  int64
#  19  earliest_cr_line        42535 non-null  int64
#  20  inq_last_6mths          42535 non-null  int64
#  21  mths_since_last_delinq  42535 non-null  int64
#  22  mths_since_last_record  42535 non-null  int64
#  23  open_acc                42535 non-null  int64
#  24  pub_rec                 42535 non-null  int64
#  25  revol_bal               42535 non-null  int64
#  26  revol_util              42535 non-null  object
#  27  total_acc               42535 non-null  int64
#  28  total_pymnt             42535 non-null  float64
#  29  total_pymnt_inv         42535 non-null  float64
#  30  last_pymnt_d            42535 non-null  int64
#  31  last_pymnt_amnt         42535 non-null  float64
#  32  next_pymnt_d            42535 non-null  int64
#  33  last_credit_pull_d      42535 non-null  int64
#  34  pub_rec_bankruptcies    42535 non-null  int64
#  35  loan_status             42535 non-null  object
# dtypes: float64(7), int64(18), object(11)
# memory usage: 11.7+ MB

# %%
dataset.isnull().sum()
# Out:
# loan_amnt                 0
# funded_amnt               0
# funded_amnt_inv           0
# term                      0
# int_rate                  0
# installment               0
# grade                     0
# sub_grade                 0
# emp_length                0
# home_ownership            0
# annual_inc                4
# verification_status       0
# issue_days                0
# Credit_requirements       0
# purpose                   0
# zip_code                  0
# addr_state                0
# dti                       0
# delinq_2yrs               0
# earliest_cr_line          0
# inq_last_6mths            0
# mths_since_last_delinq    0
# mths_since_last_record    0
# open_acc                  0
# pub_rec                   0
# revol_bal                 0
# revol_util                0
# total_acc                 0
# total_pymnt               0
# total_pymnt_inv           0
# last_pymnt_d              0
# last_pymnt_amnt           0
# next_pymnt_d              0
# last_credit_pull_d        0
# pub_rec_bankruptcies      0
# loan_status               0
# dtype: int64

# %%
#There were only 4 missing values in the annual_inc column so i dropped them 
dataset.dropna(axis=0, inplace=True)
dataset.isnull().any().sum()
# Out:
# 0

# %%
dataset.isnull().any().any()
# Out:
# False

# %%
#Label Encoding loan_status to loan_status_labeled for EDA purposes
dataset['loan_status_labeled'] = dataset['loan_status'].map({'Fully Paid': 0,
                                                             'Charged Off': 1})

# %% [markdown]
# Specifying numerical and categorical columns to analyze each

# %%
numerical_cols = [col for col in dataset.columns if dataset[col].dtype in ['int64','float64']]
numerical_cols
# Out:
# ['loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'installment',
#  'emp_length',
#  'annual_inc',
#  'issue_days',
#  'zip_code',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'total_acc',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'pub_rec_bankruptcies',
#  'loan_status_labeled']

# %%
categorical_cols = [col for col in dataset.columns if dataset[col].dtype == 'object']
categorical_cols
# Out:
# ['term',
#  'int_rate',
#  'grade',
#  'sub_grade',
#  'home_ownership',
#  'verification_status',
#  'Credit_requirements',
#  'purpose',
#  'addr_state',
#  'revol_util',
#  'loan_status']

# %%
#int_rate had object dtype
dataset['int_rate'].head(1)
# Out:
# 0    11.83%
# Name: int_rate, dtype: object

# %%
#Removnig '%' from the int_rate column
dataset['int_rate'] = dataset['int_rate'].apply(lambda x: x.replace('%', ''))
dataset['int_rate'].value_counts()
# Out:
# 10.99    970
# 11.49    837
# 13.49    832
# 7.51     787
# 7.88     742
#         ...
# 17.41      1
# 24.59      1
# 17.46      1
# 16.83      1
# 17.72      1
# Name: int_rate, Length: 394, dtype: int64

# %%
#revol_util had % same as int_rate and object dtype 
dataset['revol_util'].head(1)
# Out:
# 0    38.70%
# Name: revol_util, dtype: object

# %%
#Removing the '%' from revol_util column
dataset['revol_util'] = dataset['revol_util'].apply(lambda x: x.replace('%', ''))
dataset['revol_util'].value_counts()
# Out:
# 0.00      1156
# 40.70       65
# 0.20        64
# 63.00       63
# 66.60       62
#           ...
# 0.86         1
# 70.26        1
# 26.32        1
# 106.40       1
# 105.70       1
# Name: revol_util, Length: 1119, dtype: int64

# %% [markdown]
# Changing the dtype of int_rate and revol_util to float64

# %%
dataset['int_rate'] = dataset['int_rate'].astype('float64')
dataset['int_rate'].dtype
# Out:
# dtype('float64')

# %%
dataset['revol_util'] = dataset['revol_util'].astype('float64')
dataset['revol_util'].dtype
# Out:
# dtype('float64')

# %%
#Updating numerical and categorical columns
numerical_cols = [col for col in dataset.columns if dataset[col].dtype in ['int64','float64']]
print('Numerical Columns:', numerical_cols)
categorical_cols = [col for col in dataset.columns if dataset[col].dtype == 'object']
print('Categorical Columns:', categorical_cols)
# Out:
# Numerical Columns: ['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'int_rate', 'installment', 'emp_length', 'annual_inc', 'issue_days', 'zip_code', 'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'total_pymnt', 'total_pymnt_inv', 'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d', 'pub_rec_bankruptcies', 'loan_status_labeled']
# Categorical Columns: ['term', 'grade', 'sub_grade', 'home_ownership', 'verification_status', 'Credit_requirements', 'purpose', 'addr_state', 'loan_status']

# %% [markdown]
# # Categorical Columns EDA

# %% [raw]
# -term: The number of payments on the loan. Values are in months and can be either 36 or 60.
#
# -grade: LC assigned loan grade/assigned quality score to a loan based on a borrower's credit history, quality of the collateral,  and the likelihood of repayment of the principal and interest.
#
# -subgrade: LC assigned loan subgrade.
#
# -home_ownership: The home ownership status provided by the borrower during registration.
#
# -verification_status: Indicates if income was verified by LC, not verified, or if the income source was verified.
#
# -Credit_requirements.
#
# -purpose: A category provided by the borrower for the loan request.
#
# -addr_state: The state provided by the borrower in the loan application.

# %%
#Categorical plots for categorical features
plt.figure(figsize=(8,4))
for col in categorical_cols:
    sns.catplot(x=col, y='loan_status_labeled', data=dataset, kind='point', aspect=2)
    plt.xticks(rotation=45)
    plt.ylim(0, 1)  #Ylim makes the y axis Min->0 and Max->1  #Comment the ylim if you want to see the exact values on the y-axis

# %% [markdown]
# # Insights from the CatPlots:

# %% [raw]
# *Loans that had a 36 months term were slightly better at being Fully Paid(0.12) than loans with 60 months term(0.24). Also the number of loans that were taken on a 36 month term in the dataset were double the loans that were taken on a 60 month term (Check the countplot Below).
#
# *Better grades of a loan had a lower chance at being Charged Off.
#
# *Subgrade had the same insights as grade BUT note that in grade G had the highest chance of being charged off of all the grades and in sub_grade F5 and F4 had a higher chance of being charged off than G5 and G4 while F3,F2 and F1 had a lower chance at being charged off than G3,G2 and G1.
#
# *Home ownership were all close to each other while OTHER and NONE categories slightly higher at being Charged Off. Also the lowest number of loans handed had OTHER and NONE categories as their home_ownership (Check the countplot Below).
#
# *Verification status: All close to each other.
#
# *Credit Requirements: Yes had more chance at being Fully Paid than No. (Check the number of loans that had NO as credit_requirement from the countplot below).
#
# *Purpose: small business category had the highest chance of being Charged Off while the cars category had the highest probability of being Fully Paid.
#
# *addr_state: Loans with NE state had a very high chance to be Charged Off while loans with ME as state had the lowest chance of being Charged Off.

# %%
for i in ['term','grade','home_ownership','Credit_requirements']:
    sns.countplot(x=i, data=dataset, )
    plt.title(i+'_count')
    plt.show()

# %% [markdown]
# # Numerical Columns EDA

# %%
dataset[numerical_cols].describe()
# Out:
#           loan_amnt   funded_amnt  funded_amnt_inv      int_rate  \
# count  42531.000000  42531.000000     42531.000000  42531.000000
# mean   11090.173050  10822.011004     10140.582662     12.165424
# std     7411.137529   7147.112309      7131.587121      3.707870
# min      500.000000    500.000000         0.000000      5.420000
# 25%     5200.000000   5000.000000      4950.000000      9.630000
# 50%     9700.000000   9600.000000      8500.000000     11.990000
# 75%    15000.000000  15000.000000     14000.000000     14.720000
# max    35000.000000  35000.000000     35000.000000     24.590000
#
#         installment    emp_length    annual_inc    issue_days      zip_code  \
# count  42531.000000  42531.000000  4.253100e+04  42531.000000  42531.000000
# mean     322.634879      4.913757  6.913656e+04    161.110390  49996.762362
# std      208.933353      3.461547  6.409635e+04    103.855489  32847.121955
# min       15.670000      0.000000  1.896000e+03     12.000000    700.000000
# 25%      165.520000      2.000000  4.000000e+04     73.000000  20000.000000
# 50%      277.710000      4.000000  5.900000e+04    165.000000  44600.000000
# 75%      428.275000      9.000000  8.250000e+04    256.000000  85000.000000
# max     1305.190000     10.000000  6.000000e+06    349.000000  99900.000000
#
#                 dti   delinq_2yrs  earliest_cr_line  inq_last_6mths  \
# count  42531.000000  42531.000000      42531.000000    42531.000000
# mean      13.374136      0.152359       6433.279984        1.080788
# std        6.725675      0.512269       4452.745388        1.527231
# min        0.000000      0.000000          0.000000        0.000000
# 25%        8.200000      0.000000        319.000000        0.000000
# 50%       13.470000      0.000000       7541.000000        1.000000
# 75%       18.680000      0.000000       9153.000000        2.000000
# max       29.990000     13.000000      26654.000000       33.000000
#
#        mths_since_last_delinq  mths_since_last_record      open_acc  \
# count            42531.000000            42531.000000  42531.000000
# mean                12.851567                5.079824      9.338459
# std                 21.663753               21.576802      4.500654
# min                  0.000000                0.000000      0.000000
# 25%                  0.000000                0.000000      6.000000
# 50%                  0.000000                0.000000      9.000000
# 75%                 21.000000                0.000000     12.000000
# max                120.000000              129.000000     47.000000
#
#             pub_rec     revol_bal    revol_util     total_acc   total_pymnt  \
# count  42531.000000  4.253100e+04  42531.000000  42531.000000  42531.000000
# mean       0.058122  1.429921e+04     49.017838     22.111401  12020.729210
# std        0.245645  2.201904e+04     28.421357     11.601803   9095.034146
# min        0.000000  0.000000e+00      0.000000      0.000000      0.000000
# 25%        0.000000  3.636500e+03     25.600000     13.000000   5464.404073
# 50%        0.000000  8.823000e+03     49.600000     20.000000   9683.424655
# 75%        0.000000  1.725250e+04     72.600000     29.000000  16428.176695
# max        5.000000  1.207359e+06    119.000000     90.000000  58886.473430
#
#        total_pymnt_inv  last_pymnt_d  last_pymnt_amnt  next_pymnt_d  \
# count     42531.000000   42531.00000      42531.00000  42531.000000
# mean      11313.521348     177.37622       2613.47279     11.481155
# std        9038.631127     105.49909       4385.21018     51.531992
# min           0.000000       0.00000          0.00000      0.000000
# 25%        4793.310000      75.00000        211.09000      0.000000
# 50%        8956.580000     167.00000        528.58000      0.000000
# 75%       15544.950000     283.00000       3170.38500      0.000000
# max       58563.680000     350.00000      36115.20000    350.000000
#
#        last_credit_pull_d  pub_rec_bankruptcies  loan_status_labeled
# count        42531.000000          42531.000000         42531.000000
# mean           146.006231              0.043780             0.151207
# std             99.513685              0.205525             0.358255
# min              0.000000              0.000000             0.000000
# 25%             67.000000              0.000000             0.000000
# 50%            102.000000              0.000000             0.000000
# 75%            225.000000              0.000000             0.000000
# max            350.000000              2.000000             1.000000

# %%
#Correlation Heatmap
plt.figure(figsize=(26,14))
sns.heatmap(dataset[numerical_cols].corr(), annot=True) #annot=True
plt.show()

# %% [markdown]
# # Preprocesssing

# %%
dataset_clean = dataset.drop(['zip_code','emp_length','addr_state','loan_status'], axis=1)
dataset_clean.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0       2850         2850           2850.0   36 months     11.83        94.44
# 1      20000        20000          19950.0   60 months     17.14       498.56
# 2       6000         4500              0.0   36 months     15.70       157.55
# 3       6400         6400           6150.0   60 months     10.59       137.85
# 4       1200         1200           1200.0   36 months     13.85        40.93
#
#   grade sub_grade home_ownership  annual_inc verification_status  issue_days  \
# 0     B        B3            OWN     24000.0        Not Verified         347
# 1     E        E3       MORTGAGE     48012.0            Verified         256
# 2     E        E5       MORTGAGE     42450.0        Not Verified         137
# 3     B        B2       MORTGAGE     37000.0        Not Verified         226
# 4     C        C4            OWN     60000.0        Not Verified         316
#
#   Credit_requirements             purpose    dti  delinq_2yrs  \
# 0                 Yes  debt_consolidation  24.70            0
# 1                 Yes  debt_consolidation  13.82            2
# 2                  No         educational  23.89            0
# 3                 Yes  debt_consolidation  15.70            0
# 4                 Yes               other   3.08            0
#
#    earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0              6718               2                       0
# 1             11528               0                      13
# 2               112              12                      58
# 3              7630               0                       0
# 4                17               3                       0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 0                       0         5        0       4184        38.7
# 1                       0        13        0      14890        66.2
# 2                       0        15        0       5361        42.2
# 3                       0         9        0       8254        48.1
# 4                       0         3        0       2823        65.7
#
#    total_acc  total_pymnt  total_pymnt_inv  last_pymnt_d  last_pymnt_amnt  \
# 0          6      3228.32          3228.32           314            51.00
# 1         36     29710.84         29636.67           283           498.56
# 2         19      4836.50             0.00           316           157.55
# 3         17      7306.05          7019.34            39           137.85
# 4          8       501.76           501.76            75            40.93
#
#    next_pymnt_d  last_credit_pull_d  pub_rec_bankruptcies  loan_status_labeled
# 0             0                 128                     0                    1
# 1             0                 128                     0                    1
# 2           166                  67                     0                    1
# 3             0                  67                     0                    1
# 4             0                  67                     0                    1

# %%
X = dataset_clean.drop(['loan_status_labeled'], axis=1)
y = dataset['loan_status_labeled']

X.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0       2850         2850           2850.0   36 months     11.83        94.44
# 1      20000        20000          19950.0   60 months     17.14       498.56
# 2       6000         4500              0.0   36 months     15.70       157.55
# 3       6400         6400           6150.0   60 months     10.59       137.85
# 4       1200         1200           1200.0   36 months     13.85        40.93
#
#   grade sub_grade home_ownership  annual_inc verification_status  issue_days  \
# 0     B        B3            OWN     24000.0        Not Verified         347
# 1     E        E3       MORTGAGE     48012.0            Verified         256
# 2     E        E5       MORTGAGE     42450.0        Not Verified         137
# 3     B        B2       MORTGAGE     37000.0        Not Verified         226
# 4     C        C4            OWN     60000.0        Not Verified         316
#
#   Credit_requirements             purpose    dti  delinq_2yrs  \
# 0                 Yes  debt_consolidation  24.70            0
# 1                 Yes  debt_consolidation  13.82            2
# 2                  No         educational  23.89            0
# 3                 Yes  debt_consolidation  15.70            0
# 4                 Yes               other   3.08            0
#
#    earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0              6718               2                       0
# 1             11528               0                      13
# 2               112              12                      58
# 3              7630               0                       0
# 4                17               3                       0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 0                       0         5        0       4184        38.7
# 1                       0        13        0      14890        66.2
# 2                       0        15        0       5361        42.2
# 3                       0         9        0       8254        48.1
# 4                       0         3        0       2823        65.7
#
#    total_acc  total_pymnt  total_pymnt_inv  last_pymnt_d  last_pymnt_amnt  \
# 0          6      3228.32          3228.32           314            51.00
# 1         36     29710.84         29636.67           283           498.56
# 2         19      4836.50             0.00           316           157.55
# 3         17      7306.05          7019.34            39           137.85
# 4          8       501.76           501.76            75            40.93
#
#    next_pymnt_d  last_credit_pull_d  pub_rec_bankruptcies
# 0             0                 128                     0
# 1             0                 128                     0
# 2           166                  67                     0
# 3             0                  67                     0
# 4             0                  67                     0

# %%
y.shape
# Out:
# (42531,)

# %%
#Splitting the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print('X_train shape:',X_train.shape)
print('X_test shape:',X_test.shape)
# Out:
# X_train shape: (34024, 32)
# X_test shape: (8507, 32)

# %%
X_train.head()
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 41169      35000        35000      33951.84413   60 months     20.89
# 6012       16000        16000      14864.69006   36 months      5.79
# 31115      21000        21000      20950.00000   36 months     11.99
# 34992      14000        14000      13950.00000   36 months      9.63
# 36891      17200        17200      17200.00000   60 months     20.89
#
#        installment grade sub_grade home_ownership  annual_inc  \
# 41169       944.71     F        F1       MORTGAGE    160000.0
# 6012        485.24     A        A2       MORTGAGE     95004.0
# 31115       697.41     B        B5       MORTGAGE    175000.0
# 34992       449.32     B        B1       MORTGAGE    112000.0
# 36891       464.26     F        F1           RENT     52000.0
#
#       verification_status  issue_days Credit_requirements             purpose  \
# 41169            Verified          42                 Yes  debt_consolidation
# 6012      Source Verified          74                 Yes               other
# 31115     Source Verified         134                 Yes      major_purchase
# 34992     Source Verified         315                 Yes         credit_card
# 36891            Verified          12                 Yes               house
#
#          dti  delinq_2yrs  earliest_cr_line  inq_last_6mths  \
# 41169  12.11            0              7145               1
# 6012   15.51            0             10067               1
# 31115  10.99            3              7296               2
# 34992   8.42            0             14023               0
# 36891   7.06            0                19               0
#
#        mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 41169                       0                      88        13        2
# 6012                        0                       0         7        0
# 31115                       8                       0         9        0
# 34992                      36                       0        10        0
# 36891                       0                       0         5        0
#
#        revol_bal  revol_util  total_acc  total_pymnt  total_pymnt_inv  \
# 41169      34165        91.4         21  56681.88585         54132.56
# 6012        4619        27.5         18  17364.93173         16037.44
# 31115       5438        40.0         20  25085.71686         25025.99
# 34992      19783        33.2         24  16133.15156         16075.53
# 36891       8190        96.4          6  27885.22002         27885.22
#
#        last_pymnt_d  last_pymnt_amnt  next_pymnt_d  last_credit_pull_d  \
# 41169            38           943.99             0                  67
# 6012            314          4766.10             0                 284
# 31115           193          2072.89             0                  67
# 34992            11           331.17             0                  67
# 36891             8           920.52             0                  38
#
#        pub_rec_bankruptcies
# 41169                     2
# 6012                      0
# 31115                     0
# 34992                     0
# 36891                     0

# %%
#loan_amnt/funded_amnt/funded_amnt_inv had super high correlation >93% for all
#Maybe combine them to 1 feature using PCA
pass

# %%
threshold = 0.80    #Come back to check the correlation threshhold
correlated_features = set()
correlation_matrix = X_train.corr()
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[j, i]) > threshold:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
            
len(correlated_features)
# Out:
# 7

# %%
#Number of columns in the dataset, with correlation value of greater than 0.8 with at least 1 other column
print(correlated_features)
# Out:
# {'funded_amnt', 'installment', 'total_pymnt', 'pub_rec', 'funded_amnt_inv', 'pub_rec_bankruptcies', 'total_pymnt_inv'}

# %%
X_train_clean = X_train.drop(correlated_features, axis=1)
plt.figure(figsize=(26,14))
sns.heatmap(X_train_clean.corr(), annot=True) #annot=True
plt.show()

# %%
X_train_clean.shape
# Out:
# (34024, 25)

# %%
categorical_cols = [col for col in X_train_clean.columns if X_train_clean[col].dtype == 'object']
numerical_cols =[col for col in X_train_clean.columns if X_train_clean[col].dtype in ['int64','float64']]

# %%
X_train_clean[categorical_cols].head()
# Out:
#              term grade sub_grade home_ownership verification_status  \
# 41169   60 months     F        F1       MORTGAGE            Verified
# 6012    36 months     A        A2       MORTGAGE     Source Verified
# 31115   36 months     B        B5       MORTGAGE     Source Verified
# 34992   36 months     B        B1       MORTGAGE     Source Verified
# 36891   60 months     F        F1           RENT            Verified
#
#       Credit_requirements             purpose
# 41169                 Yes  debt_consolidation
# 6012                  Yes               other
# 31115                 Yes      major_purchase
# 34992                 Yes         credit_card
# 36891                 Yes               house

# %%
#Drop subgrade since grade is more generalized (Maybe better?!?!)
X_train_clean.drop('sub_grade', axis=1, inplace=True)
categorical_cols = [col for col in X_train_clean.columns if X_train_clean[col].dtype == 'object']

# %%
#I've tried to map the term to 0's and 1's but it resulted in NANs so i used strip() to remove outer spaces
X_train_clean['term'] = X_train_clean['term'].apply(lambda x: x.strip())
X_train_clean['term']
# Out:
# 41169    60 months
# 6012     36 months
# 31115    36 months
# 34992    36 months
# 36891    60 months
#            ...
# 41993    36 months
# 32103    36 months
# 30403    36 months
# 21243    60 months
# 2732     36 months
# Name: term, Length: 34024, dtype: object

# %%
X_train_clean['home_ownership'].value_counts()
# Out:
# RENT        16179
# MORTGAGE    15136
# OWN          2598
# OTHER         108
# NONE            3
# Name: home_ownership, dtype: int64

# %%
X_train_clean['term_label'] = X_train_clean['term'].map({'36 months': 0, '60 months': 1})
X_train_clean['grade_label'] = X_train_clean['grade'].map({'A':0, 'B':1, 'C':2, 'D':3, 'E':4, 'F':5, 'G':6})
X_train_clean['home_ownership_label'] = X_train_clean['home_ownership'].replace(['RENT','MORTGAGE','OWN'],0)
X_train_clean['home_ownership_label'] = X_train_clean['home_ownership_label'].replace(['OTHER','NONE'],1)
X_train_clean['verification_status_label'] = X_train_clean['verification_status'].map({'Not Verified':0, 'Source Verified':1, 'Verified':2})
X_train_clean['Credit_requirements_label'] = X_train_clean['Credit_requirements'].map({'No': 0, 'Yes':1})

X_train_clean['purpose_label'] = X_train_clean['purpose'].replace(['small_business','educational','renewable_energy'],0)
X_train_clean['purpose_label'] = X_train_clean['purpose_label'].replace(['other','moving','medical','house','debt_consolidation'],1)
X_train_clean['purpose_label'] = X_train_clean['purpose_label'].replace(['vacation','home_improvement','credit_card','wedding','car','major_purchase'],2)

# %%
#small_business and educationalpurposes had slightly higher chance of being Charged Off
dataset.groupby('purpose')['loan_status_labeled'].mean().sort_values(ascending=False)
# Out:
# purpose
# small_business        0.276606
# educational           0.208531
# renewable_energy      0.188679
# other                 0.171454
# moving                0.170111
# medical               0.169987
# house                 0.164319
# debt_consolidation    0.155947
# vacation              0.147500
# home_improvement      0.131916
# credit_card           0.112653
# wedding               0.108566
# car                   0.107121
# major_purchase        0.106015
# Name: loan_status_labeled, dtype: float64

# %%
X_train_clean['purpose'].value_counts()
# Out:
# debt_consolidation    15882
# credit_card            4428
# other                  3532
# home_improvement       2522
# major_purchase         1842
# small_business         1571
# car                    1274
# wedding                 782
# medical                 612
# moving                  511
# educational             340
# house                   324
# vacation                321
# renewable_energy         83
# Name: purpose, dtype: int64

# %%
X_train_clean['purpose_label'].value_counts()
# Out:
# 1    20861
# 2    11169
# 0     1994
# Name: purpose_label, dtype: int64

# %%
for i in ['term_label','grade_label','home_ownership_label','verification_status_label','Credit_requirements_label','purpose_label']:
    categorical_cols.append(i)

# %%
X_train_clean[categorical_cols].head()
# Out:
#             term grade home_ownership verification_status Credit_requirements  \
# 41169  60 months     F       MORTGAGE            Verified                 Yes
# 6012   36 months     A       MORTGAGE     Source Verified                 Yes
# 31115  36 months     B       MORTGAGE     Source Verified                 Yes
# 34992  36 months     B       MORTGAGE     Source Verified                 Yes
# 36891  60 months     F           RENT            Verified                 Yes
#
#                   purpose  term_label  grade_label  home_ownership_label  \
# 41169  debt_consolidation           1            5                     0
# 6012                other           0            0                     0
# 31115      major_purchase           0            1                     0
# 34992         credit_card           0            1                     0
# 36891               house           1            5                     0
#
#        verification_status_label  Credit_requirements_label  purpose_label
# 41169                          2                          1              1
# 6012                           1                          1              1
# 31115                          1                          1              2
# 34992                          1                          1              2
# 36891                          2                          1              1

# %%
categorical_cols = ['term_label','grade_label','home_ownership_label','verification_status_label','Credit_requirements_label','purpose_label']

# %%
#Dropping Unencoded columns
print(X_train_clean.shape)
X_train_clean.drop(['term','grade','home_ownership','verification_status','Credit_requirements','purpose'], axis=1, inplace=True)
print(X_train_clean.shape)
# Out:
# (34024, 30)
# (34024, 24)

# %%
X_train_clean.head()
# Out:
#        loan_amnt  int_rate  annual_inc  issue_days    dti  delinq_2yrs  \
# 41169      35000     20.89    160000.0          42  12.11            0
# 6012       16000      5.79     95004.0          74  15.51            0
# 31115      21000     11.99    175000.0         134  10.99            3
# 34992      14000      9.63    112000.0         315   8.42            0
# 36891      17200     20.89     52000.0          12   7.06            0
#
#        earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 41169              7145               1                       0
# 6012              10067               1                       0
# 31115              7296               2                       8
# 34992             14023               0                      36
# 36891                19               0                       0
#
#        mths_since_last_record  open_acc  revol_bal  revol_util  total_acc  \
# 41169                      88        13      34165        91.4         21
# 6012                        0         7       4619        27.5         18
# 31115                       0         9       5438        40.0         20
# 34992                       0        10      19783        33.2         24
# 36891                       0         5       8190        96.4          6
#
#        last_pymnt_d  last_pymnt_amnt  next_pymnt_d  last_credit_pull_d  \
# 41169            38           943.99             0                  67
# 6012            314          4766.10             0                 284
# 31115           193          2072.89             0                  67
# 34992            11           331.17             0                  67
# 36891             8           920.52             0                  38
#
#        term_label  grade_label  home_ownership_label  \
# 41169           1            5                     0
# 6012            0            0                     0
# 31115           0            1                     0
# 34992           0            1                     0
# 36891           1            5                     0
#
#        verification_status_label  Credit_requirements_label  purpose_label
# 41169                          2                          1              1
# 6012                           1                          1              1
# 31115                          1                          1              2
# 34992                          1                          1              2
# 36891                          2                          1              1

# %%
X_train_clean[numerical_cols].head()
# Out:
#        loan_amnt  int_rate  annual_inc  issue_days    dti  delinq_2yrs  \
# 41169      35000     20.89    160000.0          42  12.11            0
# 6012       16000      5.79     95004.0          74  15.51            0
# 31115      21000     11.99    175000.0         134  10.99            3
# 34992      14000      9.63    112000.0         315   8.42            0
# 36891      17200     20.89     52000.0          12   7.06            0
#
#        earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 41169              7145               1                       0
# 6012              10067               1                       0
# 31115              7296               2                       8
# 34992             14023               0                      36
# 36891                19               0                       0
#
#        mths_since_last_record  open_acc  revol_bal  revol_util  total_acc  \
# 41169                      88        13      34165        91.4         21
# 6012                        0         7       4619        27.5         18
# 31115                       0         9       5438        40.0         20
# 34992                       0        10      19783        33.2         24
# 36891                       0         5       8190        96.4          6
#
#        last_pymnt_d  last_pymnt_amnt  next_pymnt_d  last_credit_pull_d
# 41169            38           943.99             0                  67
# 6012            314          4766.10             0                 284
# 31115           193          2072.89             0                  67
# 34992            11           331.17             0                  67
# 36891             8           920.52             0                  38

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_clean[numerical_cols] = sc.fit_transform(X_train_clean[numerical_cols])
X_train_clean[numerical_cols].head()
# Out:
#        loan_amnt  int_rate  annual_inc  issue_days       dti  delinq_2yrs  \
# 41169   3.237412  2.351010    1.375021   -1.144604 -0.189711    -0.296516
# 6012    0.665233 -1.719320    0.392181   -0.836684  0.315396    -0.296516
# 31115   1.342122 -0.048059    1.601844   -0.259335 -0.356099     5.503796
# 34992   0.394477 -0.684216    0.649187    1.482338 -0.737901    -0.296516
# 36891   0.827686  2.351010   -0.258106   -1.433279 -0.939944    -0.296516
#
#        earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 41169          0.159446       -0.050361               -0.592104
# 6012           0.815328       -0.050361               -0.592104
# 31115          0.193340        0.614817               -0.222552
# 34992          1.703306       -0.715540                1.070884
# 36891         -1.440081       -0.715540               -0.592104
#
#        mths_since_last_record  open_acc  revol_bal  revol_util  total_acc  \
# 41169                3.835435  0.815309   0.934528    1.492918  -0.093988
# 6012                -0.235783 -0.520468  -0.447488   -0.758130  -0.353349
# 31115               -0.235783 -0.075209  -0.409180   -0.317784  -0.180441
# 34992               -0.235783  0.147421   0.261809   -0.557332   0.165373
# 36891               -0.235783 -0.965727  -0.280455    1.669056  -1.390793
#
#        last_pymnt_d  last_pymnt_amnt  next_pymnt_d  last_credit_pull_d
# 41169     -1.318106        -0.381546      -0.22233           -0.793195
# 6012       1.298885         0.487279      -0.22233            1.390063
# 31115      0.151581        -0.124929      -0.22233           -0.793195
# 34992     -1.574116        -0.520850      -0.22233           -0.793195
# 36891     -1.602561        -0.386881      -0.22233           -1.084967

# %%
X_train_clean.head()
# Out:
#        loan_amnt  int_rate  annual_inc  issue_days       dti  delinq_2yrs  \
# 41169   3.237412  2.351010    1.375021   -1.144604 -0.189711    -0.296516
# 6012    0.665233 -1.719320    0.392181   -0.836684  0.315396    -0.296516
# 31115   1.342122 -0.048059    1.601844   -0.259335 -0.356099     5.503796
# 34992   0.394477 -0.684216    0.649187    1.482338 -0.737901    -0.296516
# 36891   0.827686  2.351010   -0.258106   -1.433279 -0.939944    -0.296516
#
#        earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 41169          0.159446       -0.050361               -0.592104
# 6012           0.815328       -0.050361               -0.592104
# 31115          0.193340        0.614817               -0.222552
# 34992          1.703306       -0.715540                1.070884
# 36891         -1.440081       -0.715540               -0.592104
#
#        mths_since_last_record  open_acc  revol_bal  revol_util  total_acc  \
# 41169                3.835435  0.815309   0.934528    1.492918  -0.093988
# 6012                -0.235783 -0.520468  -0.447488   -0.758130  -0.353349
# 31115               -0.235783 -0.075209  -0.409180   -0.317784  -0.180441
# 34992               -0.235783  0.147421   0.261809   -0.557332   0.165373
# 36891               -0.235783 -0.965727  -0.280455    1.669056  -1.390793
#
#        last_pymnt_d  last_pymnt_amnt  next_pymnt_d  last_credit_pull_d  \
# 41169     -1.318106        -0.381546      -0.22233           -0.793195
# 6012       1.298885         0.487279      -0.22233            1.390063
# 31115      0.151581        -0.124929      -0.22233           -0.793195
# 34992     -1.574116        -0.520850      -0.22233           -0.793195
# 36891     -1.602561        -0.386881      -0.22233           -1.084967
#
#        term_label  grade_label  home_ownership_label  \
# 41169           1            5                     0
# 6012            0            0                     0
# 31115           0            1                     0
# 34992           0            1                     0
# 36891           1            5                     0
#
#        verification_status_label  Credit_requirements_label  purpose_label
# 41169                          2                          1              1
# 6012                           1                          1              1
# 31115                          1                          1              2
# 34992                          1                          1              2
# 36891                          2                          1              1

# %% [markdown]
# # Model 1

# %%
#Fitting a baseline model
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))

    means = results.cv_results_['mean_test_score']
    for mean, params in zip(means, results.cv_results_['params']):
        print('{} for {}'.format(round(mean, 3), params))

rfc = RandomForestClassifier(random_state=0)
parameters = {
    'n_estimators': [2**i for i in range(3, 10)],
    'max_depth': [2, 4, 8, 16, 32, None]
}

cv = GridSearchCV(rfc, parameters, cv=5, n_jobs=-1)
cv.fit(X_train_clean, y_train.values.ravel())

print_results(cv)
# Out:
# BEST PARAMS: {'max_depth': 32, 'n_estimators': 256}
#
# 0.849 for {'max_depth': 2, 'n_estimators': 8}
# 0.849 for {'max_depth': 2, 'n_estimators': 16}
# 0.849 for {'max_depth': 2, 'n_estimators': 32}
# 0.849 for {'max_depth': 2, 'n_estimators': 64}
# 0.849 for {'max_depth': 2, 'n_estimators': 128}
# 0.849 for {'max_depth': 2, 'n_estimators': 256}
# 0.849 for {'max_depth': 2, 'n_estimators': 512}
# 0.865 for {'max_depth': 4, 'n_estimators': 8}
# 0.854 for {'max_depth': 4, 'n_estimators': 16}
# 0.851 for {'max_depth': 4, 'n_estimators': 32}
# 0.851 for {'max_depth': 4, 'n_estimators': 64}
# 0.85 for {'max_depth': 4, 'n_estimators': 128}
# 0.85 for {'max_depth': 4, 'n_estimators': 256}
# 0.851 for {'max_depth': 4, 'n_estimators': 512}
# 0.909 for {'max_depth': 8, 'n_estimators': 8}
# 0.906 for {'max_depth': 8, 'n_estimators': 16}
# 0.902 for {'max_depth': 8, 'n_estimators': 32}
# 0.899 for {'max_depth': 8, 'n_estimators': 64}
# 0.903 for {'max_depth': 8, 'n_estimators': 128}
# 0.904 for {'max_depth': 8, 'n_estimators': 256}
# 0.905 for {'max_depth': 8, 'n_estimators': 512}
# 0.914 for {'max_depth': 16, 'n_estimators': 8}
# 0.92 for {'max_depth': 16, 'n_estimators': 16}
# 0.922 for {'max_depth': 16, 'n_estimators': 32}
# 0.922 for {'max_depth': 16, 'n_estimators': 64}
# 0.923 for {'max_depth': 16, 'n_estimators': 128}
# 0.923 for {'max_depth': 16, 'n_estimators': 256}
# 0.924 for {'max_depth': 16, 'n_estimators': 512}
# 0.913 for {'max_depth': 32, 'n_estimators': 8}
# 0.918 for {'max_depth': 32, 'n_estimators': 16}
# 0.922 for {'max_depth': 32, 'n_estimators': 32}
# 0.925 for {'max_depth': 32, 'n_estimators': 64}
# 0.926 for {'max_depth': 32, 'n_estimators': 128}
# 0.926 for {'max_depth': 32, 'n_estimators': 256}
# 0.926 for {'max_depth': 32, 'n_estimators': 512}
# 0.914 for {'max_depth': None, 'n_estimators': 8}
# 0.919 for {'max_depth': None, 'n_estimators': 16}
# 0.923 for {'max_depth': None, 'n_estimators': 32}
# 0.925 for {'max_depth': None, 'n_estimators': 64}
# 0.926 for {'max_depth': None, 'n_estimators': 128}
# 0.926 for {'max_depth': None, 'n_estimators': 256}
# 0.926 for {'max_depth': None, 'n_estimators': 512}

# %%
# Generate feature importance plot
plt.figure(figsize=(15,10))
feat_imp = cv.best_estimator_.feature_importances_
indices = np.argsort(feat_imp)
plt.yticks(range(len(indices)), [X_train_clean.columns[i] for i in indices])
plt.barh(range(len(indices)), feat_imp[indices], color='r', align='center')
plt.show()

# %% [markdown]
# # Model 2

# %% [markdown]
# ### Based on the Top 10 Features

# %%
#Building a model based on the Top 10 important features
selected_features10 = ['last_credit_pull_d','last_pymnt_amnt','last_pymnt_d','int_rate','issue_days','annual_inc','revol_util','dti','loan_amnt','revol_bal']

X_train_clean_top_10_features = X_train_clean[selected_features10]
X_train_clean_top_10_features.head()
# Out:
#        last_credit_pull_d  last_pymnt_amnt  last_pymnt_d  int_rate  \
# 41169           -0.793195        -0.381546     -1.318106  2.351010
# 6012             1.390063         0.487279      1.298885 -1.719320
# 31115           -0.793195        -0.124929      0.151581 -0.048059
# 34992           -0.793195        -0.520850     -1.574116 -0.684216
# 36891           -1.084967        -0.386881     -1.602561  2.351010
#
#        issue_days  annual_inc  revol_util       dti  loan_amnt  revol_bal
# 41169   -1.144604    1.375021    1.492918 -0.189711   3.237412   0.934528
# 6012    -0.836684    0.392181   -0.758130  0.315396   0.665233  -0.447488
# 31115   -0.259335    1.601844   -0.317784 -0.356099   1.342122  -0.409180
# 34992    1.482338    0.649187   -0.557332 -0.737901   0.394477   0.261809
# 36891   -1.433279   -0.258106    1.669056 -0.939944   0.827686  -0.280455

# %%
rfc = RandomForestClassifier(random_state=0)
model2 = GridSearchCV(rfc, parameters, cv=5, n_jobs=-1)
model2.fit(X_train_clean_top_10_features, y_train.values.ravel())

print_results(model2)
# Out:
# BEST PARAMS: {'max_depth': None, 'n_estimators': 256}
#
# 0.849 for {'max_depth': 2, 'n_estimators': 8}
# 0.849 for {'max_depth': 2, 'n_estimators': 16}
# 0.849 for {'max_depth': 2, 'n_estimators': 32}
# 0.851 for {'max_depth': 2, 'n_estimators': 64}
# 0.85 for {'max_depth': 2, 'n_estimators': 128}
# 0.849 for {'max_depth': 2, 'n_estimators': 256}
# 0.849 for {'max_depth': 2, 'n_estimators': 512}
# 0.872 for {'max_depth': 4, 'n_estimators': 8}
# 0.879 for {'max_depth': 4, 'n_estimators': 16}
# 0.874 for {'max_depth': 4, 'n_estimators': 32}
# 0.882 for {'max_depth': 4, 'n_estimators': 64}
# 0.88 for {'max_depth': 4, 'n_estimators': 128}
# 0.884 for {'max_depth': 4, 'n_estimators': 256}
# 0.889 for {'max_depth': 4, 'n_estimators': 512}
# 0.914 for {'max_depth': 8, 'n_estimators': 8}
# 0.914 for {'max_depth': 8, 'n_estimators': 16}
# 0.914 for {'max_depth': 8, 'n_estimators': 32}
# 0.914 for {'max_depth': 8, 'n_estimators': 64}
# 0.914 for {'max_depth': 8, 'n_estimators': 128}
# 0.915 for {'max_depth': 8, 'n_estimators': 256}
# 0.914 for {'max_depth': 8, 'n_estimators': 512}
# 0.923 for {'max_depth': 16, 'n_estimators': 8}
# 0.926 for {'max_depth': 16, 'n_estimators': 16}
# 0.928 for {'max_depth': 16, 'n_estimators': 32}
# 0.929 for {'max_depth': 16, 'n_estimators': 64}
# 0.929 for {'max_depth': 16, 'n_estimators': 128}
# 0.929 for {'max_depth': 16, 'n_estimators': 256}
# 0.929 for {'max_depth': 16, 'n_estimators': 512}
# 0.922 for {'max_depth': 32, 'n_estimators': 8}
# 0.925 for {'max_depth': 32, 'n_estimators': 16}
# 0.929 for {'max_depth': 32, 'n_estimators': 32}
# 0.932 for {'max_depth': 32, 'n_estimators': 64}
# 0.932 for {'max_depth': 32, 'n_estimators': 128}
# 0.932 for {'max_depth': 32, 'n_estimators': 256}
# 0.932 for {'max_depth': 32, 'n_estimators': 512}
# 0.922 for {'max_depth': None, 'n_estimators': 8}
# 0.923 for {'max_depth': None, 'n_estimators': 16}
# 0.93 for {'max_depth': None, 'n_estimators': 32}
# 0.931 for {'max_depth': None, 'n_estimators': 64}
# 0.932 for {'max_depth': None, 'n_estimators': 128}
# 0.933 for {'max_depth': None, 'n_estimators': 256}
# 0.933 for {'max_depth': None, 'n_estimators': 512}

# %%
# Generate feature importance plot
plt.figure(figsize=(15,10))
feat_imp = model2.best_estimator_.feature_importances_
indices = np.argsort(feat_imp)
plt.yticks(range(len(indices)), [X_train_clean_top_10_features.columns[i] for i in indices])
plt.barh(range(len(indices)), feat_imp[indices], color='r', align='center')
plt.show()

# %% [markdown]
# # Model 3

# %% [markdown]
# ### Based on the Top 5 Features

# %%
selected_features5 = ['last_credit_pull_d','last_pymnt_amnt','last_pymnt_d','int_rate','issue_days']

X_train_clean_top_5_features = X_train_clean[selected_features5]
X_train_clean_top_5_features.head()
# Out:
#        last_credit_pull_d  last_pymnt_amnt  last_pymnt_d  int_rate  issue_days
# 41169           -0.793195        -0.381546     -1.318106  2.351010   -1.144604
# 6012             1.390063         0.487279      1.298885 -1.719320   -0.836684
# 31115           -0.793195        -0.124929      0.151581 -0.048059   -0.259335
# 34992           -0.793195        -0.520850     -1.574116 -0.684216    1.482338
# 36891           -1.084967        -0.386881     -1.602561  2.351010   -1.433279

# %%
rfc = RandomForestClassifier(random_state=0)
model3 = GridSearchCV(rfc, parameters, cv=5, n_jobs=-1)
model3.fit(X_train_clean_top_5_features, y_train.values.ravel())

print_results(model3)
# Out:
# BEST PARAMS: {'max_depth': 32, 'n_estimators': 256}
#
# 0.851 for {'max_depth': 2, 'n_estimators': 8}
# 0.851 for {'max_depth': 2, 'n_estimators': 16}
# 0.85 for {'max_depth': 2, 'n_estimators': 32}
# 0.85 for {'max_depth': 2, 'n_estimators': 64}
# 0.85 for {'max_depth': 2, 'n_estimators': 128}
# 0.85 for {'max_depth': 2, 'n_estimators': 256}
# 0.85 for {'max_depth': 2, 'n_estimators': 512}
# 0.909 for {'max_depth': 4, 'n_estimators': 8}
# 0.908 for {'max_depth': 4, 'n_estimators': 16}
# 0.909 for {'max_depth': 4, 'n_estimators': 32}
# 0.908 for {'max_depth': 4, 'n_estimators': 64}
# 0.908 for {'max_depth': 4, 'n_estimators': 128}
# 0.909 for {'max_depth': 4, 'n_estimators': 256}
# 0.909 for {'max_depth': 4, 'n_estimators': 512}
# 0.915 for {'max_depth': 8, 'n_estimators': 8}
# 0.916 for {'max_depth': 8, 'n_estimators': 16}
# 0.916 for {'max_depth': 8, 'n_estimators': 32}
# 0.916 for {'max_depth': 8, 'n_estimators': 64}
# 0.917 for {'max_depth': 8, 'n_estimators': 128}
# 0.916 for {'max_depth': 8, 'n_estimators': 256}
# 0.917 for {'max_depth': 8, 'n_estimators': 512}
# 0.931 for {'max_depth': 16, 'n_estimators': 8}
# 0.935 for {'max_depth': 16, 'n_estimators': 16}
# 0.937 for {'max_depth': 16, 'n_estimators': 32}
# 0.937 for {'max_depth': 16, 'n_estimators': 64}
# 0.938 for {'max_depth': 16, 'n_estimators': 128}
# 0.939 for {'max_depth': 16, 'n_estimators': 256}
# 0.938 for {'max_depth': 16, 'n_estimators': 512}
# 0.935 for {'max_depth': 32, 'n_estimators': 8}
# 0.938 for {'max_depth': 32, 'n_estimators': 16}
# 0.941 for {'max_depth': 32, 'n_estimators': 32}
# 0.942 for {'max_depth': 32, 'n_estimators': 64}
# 0.942 for {'max_depth': 32, 'n_estimators': 128}
# 0.942 for {'max_depth': 32, 'n_estimators': 256}
# 0.942 for {'max_depth': 32, 'n_estimators': 512}
# 0.935 for {'max_depth': None, 'n_estimators': 8}
# 0.938 for {'max_depth': None, 'n_estimators': 16}
# 0.941 for {'max_depth': None, 'n_estimators': 32}
# 0.942 for {'max_depth': None, 'n_estimators': 64}
# 0.942 for {'max_depth': None, 'n_estimators': 128}
# 0.942 for {'max_depth': None, 'n_estimators': 256}
# 0.942 for {'max_depth': None, 'n_estimators': 512}

# %%
# Generate feature importance plot
plt.figure(figsize=(15,10))
feat_imp = model3.best_estimator_.feature_importances_
indices = np.argsort(feat_imp)
plt.yticks(range(len(indices)), [X_train_clean_top_5_features.columns[i] for i in indices])
plt.barh(range(len(indices)), feat_imp[indices], color='r', align='center')
plt.show()

# %% [markdown]
# # Model 4

# %% [markdown]
# ### Baseline XGBoost

# %%
pd.DataFrame(y_train).value_counts()
# Out:
# loan_status_labeled
# 0                      28892
# 1                       5132
# dtype: int64

# %%
parameters = {
    'n_estimators': [2**i for i in range(3, 10)],
    'max_depth': [2, 4, 8, 16, 32, None],
    'scale_pos_weight':[1,5.6],
    'use_label_encoder':[False]
}
 
from xgboost import XGBClassifier
xgb = XGBClassifier(random_state=0)
model4 = GridSearchCV(xgb, parameters, cv=5, n_jobs=-1)
model4.fit(X_train_clean_top_5_features, y_train.values.ravel())

print_results(model4)
# Out:
# C:\Users\hosam\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# C:\Users\hosam\anaconda3\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [23:10:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# BEST PARAMS: {'max_depth': 4, 'n_estimators': 512, 'scale_pos_weight': 1, 'use_label_encoder': False}
#
# 0.908 for {'max_depth': 2, 'n_estimators': 8, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.851 for {'max_depth': 2, 'n_estimators': 8, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.908 for {'max_depth': 2, 'n_estimators': 16, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.847 for {'max_depth': 2, 'n_estimators': 16, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.919 for {'max_depth': 2, 'n_estimators': 32, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.863 for {'max_depth': 2, 'n_estimators': 32, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.929 for {'max_depth': 2, 'n_estimators': 64, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.882 for {'max_depth': 2, 'n_estimators': 64, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.942 for {'max_depth': 2, 'n_estimators': 128, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.904 for {'max_depth': 2, 'n_estimators': 128, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.949 for {'max_depth': 2, 'n_estimators': 256, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.921 for {'max_depth': 2, 'n_estimators': 256, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.954 for {'max_depth': 2, 'n_estimators': 512, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.934 for {'max_depth': 2, 'n_estimators': 512, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.908 for {'max_depth': 4, 'n_estimators': 8, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.851 for {'max_depth': 4, 'n_estimators': 8, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.918 for {'max_depth': 4, 'n_estimators': 16, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.872 for {'max_depth': 4, 'n_estimators': 16, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.934 for {'max_depth': 4, 'n_estimators': 32, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.895 for {'max_depth': 4, 'n_estimators': 32, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.947 for {'max_depth': 4, 'n_estimators': 64, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.921 for {'max_depth': 4, 'n_estimators': 64, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.953 for {'max_depth': 4, 'n_estimators': 128, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.937 for {'max_depth': 4, 'n_estimators': 128, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.956 for {'max_depth': 4, 'n_estimators': 256, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.947 for {'max_depth': 4, 'n_estimators': 256, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.958 for {'max_depth': 4, 'n_estimators': 512, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.954 for {'max_depth': 4, 'n_estimators': 512, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.926 for {'max_depth': 8, 'n_estimators': 8, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.883 for {'max_depth': 8, 'n_estimators': 8, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.937 for {'max_depth': 8, 'n_estimators': 16, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.901 for {'max_depth': 8, 'n_estimators': 16, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.949 for {'max_depth': 8, 'n_estimators': 32, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.937 for {'max_depth': 8, 'n_estimators': 32, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.954 for {'max_depth': 8, 'n_estimators': 64, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.948 for {'max_depth': 8, 'n_estimators': 64, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.955 for {'max_depth': 8, 'n_estimators': 128, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.954 for {'max_depth': 8, 'n_estimators': 128, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.956 for {'max_depth': 8, 'n_estimators': 256, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.956 for {'max_depth': 8, 'n_estimators': 256, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.956 for {'max_depth': 8, 'n_estimators': 512, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.956 for {'max_depth': 8, 'n_estimators': 512, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.937 for {'max_depth': 16, 'n_estimators': 8, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.926 for {'max_depth': 16, 'n_estimators': 8, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.943 for {'max_depth': 16, 'n_estimators': 16, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.938 for {'max_depth': 16, 'n_estimators': 16, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.948 for {'max_depth': 16, 'n_estimators': 32, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.946 for {'max_depth': 16, 'n_estimators': 32, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.95 for {'max_depth': 16, 'n_estimators': 64, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.949 for {'max_depth': 16, 'n_estimators': 64, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.951 for {'max_depth': 16, 'n_estimators': 128, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.951 for {'max_depth': 16, 'n_estimators': 128, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.953 for {'max_depth': 16, 'n_estimators': 256, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.953 for {'max_depth': 16, 'n_estimators': 256, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.953 for {'max_depth': 16, 'n_estimators': 512, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.953 for {'max_depth': 16, 'n_estimators': 512, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.939 for {'max_depth': 32, 'n_estimators': 8, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.933 for {'max_depth': 32, 'n_estimators': 8, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.944 for {'max_depth': 32, 'n_estimators': 16, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.939 for {'max_depth': 32, 'n_estimators': 16, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.948 for {'max_depth': 32, 'n_estimators': 32, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.945 for {'max_depth': 32, 'n_estimators': 32, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.95 for {'max_depth': 32, 'n_estimators': 64, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.948 for {'max_depth': 32, 'n_estimators': 64, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.951 for {'max_depth': 32, 'n_estimators': 128, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.95 for {'max_depth': 32, 'n_estimators': 128, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.952 for {'max_depth': 32, 'n_estimators': 256, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.951 for {'max_depth': 32, 'n_estimators': 256, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.953 for {'max_depth': 32, 'n_estimators': 512, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.951 for {'max_depth': 32, 'n_estimators': 512, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.915 for {'max_depth': None, 'n_estimators': 8, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.871 for {'max_depth': None, 'n_estimators': 8, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.931 for {'max_depth': None, 'n_estimators': 16, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.887 for {'max_depth': None, 'n_estimators': 16, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.946 for {'max_depth': None, 'n_estimators': 32, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.922 for {'max_depth': None, 'n_estimators': 32, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.953 for {'max_depth': None, 'n_estimators': 64, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.939 for {'max_depth': None, 'n_estimators': 64, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.956 for {'max_depth': None, 'n_estimators': 128, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.95 for {'max_depth': None, 'n_estimators': 128, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.958 for {'max_depth': None, 'n_estimators': 256, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.955 for {'max_depth': None, 'n_estimators': 256, 'scale_pos_weight': 5.6, 'use_label_encoder': False}
# 0.958 for {'max_depth': None, 'n_estimators': 512, 'scale_pos_weight': 1, 'use_label_encoder': False}
# 0.956 for {'max_depth': None, 'n_estimators': 512, 'scale_pos_weight': 5.6, 'use_label_encoder': False}

# %%
# Generate feature importance plot
plt.figure(figsize=(15,10))
feat_imp = model4.best_estimator_.feature_importances_
indices = np.argsort(feat_imp)
plt.yticks(range(len(indices)), [X_train_clean_top_5_features.columns[i] for i in indices])
plt.barh(range(len(indices)), feat_imp[indices], color='r', align='center')
plt.show()

# %% [markdown]
# # Testing the Model on the Test Data

# %% [markdown]
# ### Preprocessing the Test Data

# %%
X_test.head()
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 19983       1500         1500       1500.00000   36 months     18.79
# 882        10000        10000      10000.00000   36 months      9.63
# 27800      35000        35000      34929.06898   60 months     12.68
# 2005        1000         1000        950.00000   36 months     11.14
# 1136       25000        25000      24725.00000   60 months     11.49
#
#        installment grade sub_grade home_ownership  annual_inc  \
# 19983        54.83     E        E3           RENT     24000.0
# 882         320.94     B        B1           RENT     43000.0
# 27800       790.64     C        C1       MORTGAGE     82000.0
# 2005         32.81     B        B1           RENT      7200.0
# 1136        549.69     B        B4       MORTGAGE     47500.0
#
#       verification_status  issue_days Credit_requirements             purpose  \
# 19983        Not Verified         103                 Yes               other
# 882          Not Verified         346                 Yes         credit_card
# 27800            Verified         256                 Yes      small_business
# 2005         Not Verified         347                 Yes         educational
# 1136             Verified         134                 Yes  debt_consolidation
#
#          dti  delinq_2yrs  earliest_cr_line  inq_last_6mths  \
# 19983  18.65            0                81               0
# 882    10.72            0              8332               3
# 27800   8.60            0             12197               1
# 2005    9.50            0              8332               2
# 1136   14.12            0             10249               0
#
#        mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 19983                      55                       0         4        0
# 882                         0                       0        12        0
# 27800                       0                       0        10        0
# 2005                        0                       0         5        0
# 1136                        0                       0        14        0
#
#        revol_bal  revol_util  total_acc   total_pymnt  total_pymnt_inv  \
# 19983       2893        99.8         10   1973.635756          1973.64
# 882        11497        67.2         29  11090.718200         11090.72
# 27800      11294        65.0         23  15812.800000         15679.53
# 2005        1552         9.1          7   1009.490000           959.02
# 1136       28943        34.8         28  29535.126000         29210.24
#
#        last_pymnt_d  last_pymnt_amnt  next_pymnt_d  last_credit_pull_d  \
# 19983           101            57.91             0                 101
# 882             165          5967.01             0                 343
# 27800           345           790.64             0                  67
# 2005            317          1009.58             0                 317
# 1136            164         18014.61             0                 342
#
#        pub_rec_bankruptcies
# 19983                     0
# 882                       0
# 27800                     0
# 2005                      0
# 1136                      0

# %%
X_test_clean = X_test.drop(correlated_features, axis=1)
X_test_clean.shape
# Out:
# (8507, 25)

# %%
X_test_clean.drop('sub_grade', axis=1, inplace=True)
X_test_clean.shape
# Out:
# (8507, 24)

# %%
X_test_clean['term'] = X_test_clean['term'].apply(lambda x: x.strip())
X_test_clean['term_label'] = X_test_clean['term'].map({'36 months': 0, '60 months': 1})
X_test_clean['grade_label'] = X_test_clean['grade'].map({'A':0, 'B':1, 'C':2, 'D':3, 'E':4, 'F':5, 'G':6})
X_test_clean['home_ownership_label'] = X_test_clean['home_ownership'].replace(['RENT','MORTGAGE','OWN'],0)
X_test_clean['home_ownership_label'] = X_test_clean['home_ownership_label'].replace(['OTHER','NONE'],1)
X_test_clean['verification_status_label'] = X_test_clean['verification_status'].map({'Not Verified':0, 'Source Verified':1, 'Verified':2})
X_test_clean['Credit_requirements_label'] = X_test_clean['Credit_requirements'].map({'No': 0, 'Yes':1})

X_test_clean['purpose_label'] = X_test_clean['purpose'].replace(['small_business','educational','renewable_energy'],0)
X_test_clean['purpose_label'] = X_test_clean['purpose_label'].replace(['other','moving','medical','house','debt_consolidation'],1)
X_test_clean['purpose_label'] = X_test_clean['purpose_label'].replace(['vacation','home_improvement','credit_card','wedding','car','major_purchase'],2)

# %%
#Dropping Unencoded columns
print(X_test_clean.shape)
X_test_clean.drop(['term','grade','home_ownership','verification_status','Credit_requirements','purpose'], axis=1, inplace=True)
print(X_test_clean.shape)
# Out:
# (8507, 30)
# (8507, 24)

# %%
X_test_clean[numerical_cols] = sc.transform(X_test_clean[numerical_cols])
X_test_clean.head()
# Out:
#        loan_amnt  int_rate  annual_inc  issue_days       dti  delinq_2yrs  \
# 19983  -1.297746  1.784938   -0.681509   -0.557632  0.781877    -0.296516
# 882    -0.147034 -0.684216   -0.394200    1.780635 -0.396211    -0.296516
# 27800   3.237412  0.137937    0.195540    0.914610 -0.711160    -0.296516
# 2005   -1.365435 -0.277183   -0.935551    1.790257 -0.577455    -0.296516
# 1136    1.883633 -0.182838   -0.326153   -0.259335  0.108896    -0.296516
#
#        earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 19983         -1.426165       -0.715540                1.948572
# 882            0.425884        1.279995               -0.592104
# 27800          1.293435       -0.050361               -0.592104
# 2005           0.425884        0.614817               -0.592104
# 1136           0.856180       -0.715540               -0.592104
#
#        mths_since_last_record  open_acc  revol_bal  revol_util  total_acc  \
# 19983               -0.235783 -1.188357  -0.528222    1.788830  -1.044978
# 882                 -0.235783  0.592680  -0.125769    0.640408   0.597642
# 27800               -0.235783  0.147421  -0.135265    0.562907   0.078920
# 2005                -0.235783 -0.965727  -0.590948   -1.406319  -1.304339
# 1136                -0.235783  1.037939   0.690269   -0.500968   0.511188
#
#        last_pymnt_d  last_pymnt_amnt  next_pymnt_d  last_credit_pull_d  \
# 19983     -0.720749        -0.582966      -0.22233           -0.451118
# 882       -0.113911         0.760265      -0.22233            1.983667
# 27800      1.592822        -0.416405      -0.22233           -0.793195
# 2005       1.327331        -0.366637      -0.22233            1.722079
# 1136      -0.123393         3.498874      -0.22233            1.973606
#
#        term_label  grade_label  home_ownership_label  \
# 19983           0            4                     0
# 882             0            1                     0
# 27800           1            2                     0
# 2005            0            1                     0
# 1136            1            1                     0
#
#        verification_status_label  Credit_requirements_label  purpose_label
# 19983                          0                          1              1
# 882                            0                          1              2
# 27800                          2                          1              0
# 2005                           0                          1              0
# 1136                           2                          1              1

# %%
#Function to visualize a confusion matrix and print a classification report
def metrics(y_test, y_pred, plt_title):
    #Confusion Matrix Vis
    sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='g', cbar=False, cmap='magma')
    plt.title(plt_title)
    plt.xlabel('Predicted Values')
    plt.ylabel('Actual Values')
    plt.show()
    #Classification report
    print(classification_report(y_test, y_pred))

# %% [markdown]
# ### Model 1 Test all Features with RandomForest

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, recall_score
#predicting the results
y_pred = cv.predict(X_test_clean)
#validtion
metrics(y_test, y_pred, 'Model1-All Features')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96      7208
#            1       0.84      0.60      0.70      1299
#
#     accuracy                           0.92      8507
#    macro avg       0.89      0.79      0.83      8507
# weighted avg       0.92      0.92      0.92      8507

# %%
pd.DataFrame(y_test).value_counts()
# Out:
# loan_status_labeled
# 0                      7208
# 1                      1299
# dtype: int64

# %% [markdown]
# ### Model 2 Test (Best 10 Features Model) with RandomForest

# %%
X_test_clean_top_10_features = X_test_clean[selected_features10]
X_test_clean_top_10_features.head()
# Out:
#        last_credit_pull_d  last_pymnt_amnt  last_pymnt_d  int_rate  \
# 19983           -0.451118        -0.582966     -0.720749  1.784938
# 882              1.983667         0.760265     -0.113911 -0.684216
# 27800           -0.793195        -0.416405      1.592822  0.137937
# 2005             1.722079        -0.366637      1.327331 -0.277183
# 1136             1.973606         3.498874     -0.123393 -0.182838
#
#        issue_days  annual_inc  revol_util       dti  loan_amnt  revol_bal
# 19983   -0.557632   -0.681509    1.788830  0.781877  -1.297746  -0.528222
# 882      1.780635   -0.394200    0.640408 -0.396211  -0.147034  -0.125769
# 27800    0.914610    0.195540    0.562907 -0.711160   3.237412  -0.135265
# 2005     1.790257   -0.935551   -1.406319 -0.577455  -1.365435  -0.590948
# 1136    -0.259335   -0.326153   -0.500968  0.108896   1.883633   0.690269

# %%
#predicting the results
y_pred2 = model2.predict(X_test_clean_top_10_features)
#validation
metrics(y_test, y_pred2, 'Model2-10 Features')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      7208
#            1       0.85      0.65      0.74      1299
#
#     accuracy                           0.93      8507
#    macro avg       0.89      0.82      0.85      8507
# weighted avg       0.93      0.93      0.93      8507

# %% [markdown]
# ### Model 3 Test (Best 5 Features Model) with RandomForest

# %%
X_test_clean_top_5_features = X_test_clean[selected_features5]
X_test_clean_top_5_features.head()
# Out:
#        last_credit_pull_d  last_pymnt_amnt  last_pymnt_d  int_rate  issue_days
# 19983           -0.451118        -0.582966     -0.720749  1.784938   -0.557632
# 882              1.983667         0.760265     -0.113911 -0.684216    1.780635
# 27800           -0.793195        -0.416405      1.592822  0.137937    0.914610
# 2005             1.722079        -0.366637      1.327331 -0.277183    1.790257
# 1136             1.973606         3.498874     -0.123393 -0.182838   -0.259335

# %%
#predicting the results
y_pred3 = model3.predict(X_test_clean_top_5_features)
#validation
metrics(y_test, y_pred3, 'Model3 - 5Features - RandomForest')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      7208
#            1       0.86      0.73      0.79      1299
#
#     accuracy                           0.94      8507
#    macro avg       0.91      0.86      0.88      8507
# weighted avg       0.94      0.94      0.94      8507

# %% [markdown]
# Conclusion: Models 2 and 3 performed better than Model1 which included all the features.
#
# Model 3 -- (5)Features had the best performance in terms of accuracy, precision and recall than both other models.

# %% [markdown]
# ### Model 4 Test (Best 5 Features Model) with XGBoost

# %%
#predicting the results
y_pred4 = model4.predict(X_test_clean_top_5_features)
#validation
metrics(y_test, y_pred4, 'Model4 - 5Features - XGBoost')
# Out:
# C:\Users\hosam\anaconda3\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      7208
#            1       0.88      0.83      0.86      1299
#
#     accuracy                           0.96      8507
#    macro avg       0.93      0.90      0.92      8507
# weighted avg       0.96      0.96      0.96      8507

# %% [markdown]
# Best performing models were the ones with 5 features included.
# XGBoost performed better than the Random Forest model in terms of accuracy(2%), precision(2%) and recall(10%)
